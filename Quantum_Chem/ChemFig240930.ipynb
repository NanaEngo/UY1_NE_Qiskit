# %%
from rdkit import Chem

# Create a molecule from its SMILES representation
Cz_molecule = Chem.MolFromSmiles("N1C2=C(C=CC=C2)C2=C1C=CC=C2")
Cz_molecule

# %%
! mol2chemfig -zw -i direct "N1C2=C(C=CC=C2)C2=C1C=CC=C2"
# Out:
# \chemfig{\mcfabove{N}{H}-[:228]=_[:300](-[:240]=_[:180]-[:120]=_[:60]-)%
# -[:12]=_[:84](-[:156]\phantom{N})-[:24]=_[:324]-[:264]=_[:204](-[:144])}

# %%
# Create a molecule from its SMILES representation
DMAC_molecule = Chem.MolFromSmiles("CC1(C2=CC=CC=C2NC3=CC=CC=C31)C")
DMAC_molecule

# %%
!  mol2chemfig -zw -i direct "CC1(C2=CC=CC=C2NC3=CC=CC=C31)C"
# Out:
# \chemfig{-[:310](-[:50])-[:330]=_[:30]-[:330]=_[:270]-[:210]=_[:150](-[:90]%
# )-[:210]\mcfbelow{N}{H}-[:150]=_[:210]-[:150]=_[:90]-[:30]=_[:330](-[:270])%
# (-[:30])}

# %%
# Create a molecule from its SMILES representation
PX_molecule = Chem.MolFromSmiles("C1=CC=C2C(=C1)NC3=CC=CC=C3O2")
PX_molecule

# %%
!  mol2chemfig -zw -i direct "C1=CC=C2C(=C1)NC3=CC=CC=C3O2" > chemfig_file.tex

# %%
cat chemfig_file.tex
# Out:
# \chemfig{=_[:90]-[:30]=_[:330]-[:270](=_[:210]-[:150])%
# -[:330]\mcfbelow{N}{H}-[:30]=^[:330]-[:30]=^[:90]-[:150]=^[:210](-[:270])%
# -[:150]O(-[:210])}
